# %% [markdown]
# # Script to get the telemetry data of cars from Python Lib FastF1

# %%
import fastf1 as ff1
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
from datetime import timedelta

warnings.filterwarnings('ignore')
ff1.Cache.enable_cache('S:/Caching-FastF1/')
ff1.logger.set_log_level('CRITICAL')

# %% [markdown]
# The data will be taken and processed usin the Python lib [FastF1](https://docs.fastf1.dev/) and the API [Ergast](https://ergast.com/mrd/)

# %% [markdown]
# ### Demonstrating the use of the FastF1 library to get telemetry data from the F1 cars.

# %%
# First you get the session object passing the year, the round number or GP's name and the session type
session = ff1.get_session(2022, 19, 'R')
session.load()

# %%
# Get the laps
laps = session.laps
laps
# Out:
#                       Time Driver DriverNumber                LapTime  \
# 0   0 days 01:04:21.784000    VER            1 0 days 00:01:41.343000
# 1   0 days 01:06:03.480000    VER            1 0 days 00:01:41.696000
# 2   0 days 01:07:45.373000    VER            1 0 days 00:01:41.893000
# 3   0 days 01:09:27.954000    VER            1 0 days 00:01:42.581000
# 4   0 days 01:11:10.824000    VER            1 0 days 00:01:42.870000
# ..                     ...    ...          ...                    ...
# 987 0 days 01:25:41.136000    BOT           77 0 days 00:01:44.238000
# 988 0 days 01:27:25.057000    BOT           77 0 days 00:01:43.921000
# 989 0 days 01:29:08.960000    BOT           77 0 days 00:01:43.903000
# 990 0 days 01:30:52.744000    BOT           77 0 days 00:01:43.784000
# 991 0 days 01:32:27.313000    BOT           77                    NaT
#
#      LapNumber  Stint             PitOutTime PitInTime            Sector1Time  \
# 0          1.0    1.0 0 days 00:26:15.778000       NaT                    NaT
# 1          2.0    1.0                    NaT       NaT 0 days 00:00:27.804000
# 2          3.0    1.0                    NaT       NaT 0 days 00:00:27.910000
# 3          4.0    1.0                    NaT       NaT 0 days 00:00:28.030000
# 4          5.0    1.0                    NaT       NaT 0 days 00:00:28.203000
# ..         ...    ...                    ...       ...                    ...
# 987       13.0    2.0                    NaT       NaT 0 days 00:00:28.231000
# 988       14.0    2.0                    NaT       NaT 0 days 00:00:28.299000
# 989       15.0    2.0                    NaT       NaT 0 days 00:00:28.186000
# 990       16.0    2.0                    NaT       NaT 0 days 00:00:28.081000
# 991       17.0    2.0                    NaT       NaT                    NaT
#
#                Sector2Time  ... FreshTyre             Team  \
# 0   0 days 00:00:40.647000  ...      True  Red Bull Racing
# 1   0 days 00:00:40.703000  ...      True  Red Bull Racing
# 2   0 days 00:00:40.636000  ...      True  Red Bull Racing
# 3   0 days 00:00:40.805000  ...      True  Red Bull Racing
# 4   0 days 00:00:41.199000  ...      True  Red Bull Racing
# ..                     ...  ...       ...              ...
# 987 0 days 00:00:41.673000  ...      True       Alfa Romeo
# 988 0 days 00:00:41.714000  ...      True       Alfa Romeo
# 989 0 days 00:00:41.677000  ...      True       Alfa Romeo
# 990 0 days 00:00:41.513000  ...      True       Alfa Romeo
# 991                    NaT  ...      True       Alfa Romeo
#
#               LapStartTime            LapStartDate  TrackStatus  Position  \
# 0   0 days 01:02:40.170000 2022-10-23 19:03:40.181            2       1.0
# 1   0 days 01:04:21.784000 2022-10-23 19:05:21.795            1       1.0
# 2   0 days 01:06:03.480000 2022-10-23 19:07:03.491            1       1.0
# 3   0 days 01:07:45.373000 2022-10-23 19:08:45.384            1       1.0
# 4   0 days 01:09:27.954000 2022-10-23 19:10:27.965            1       1.0
# ..                     ...                     ...          ...       ...
# 987 0 days 01:23:56.898000 2022-10-23 19:24:56.909            1      14.0
# 988 0 days 01:25:41.136000 2022-10-23 19:26:41.147            1      14.0
# 989 0 days 01:27:25.057000 2022-10-23 19:28:25.068            1      13.0
# 990 0 days 01:29:08.960000 2022-10-23 19:30:08.971            1      13.0
# 991 0 days 01:30:52.744000                     NaT          NaN       NaN
#
#      Deleted  DeletedReason FastF1Generated IsAccurate
# 0      False                          False      False
# 1      False                          False       True
# 2      False                          False       True
# 3      False                          False       True
# 4      False                          False       True
# ..       ...            ...             ...        ...
# 987    False                          False       True
# 988    False                          False       True
# 989    False                          False       True
# 990    False                          False       True
# 991    False            NaN            True      False
#
# [992 rows x 31 columns]

# %%
# From the laps, you pick a driver, and then you can get the fastest lap of that driver
fastest = laps.pick_driver('VER').pick_fastest()
fastest
# Out:
# Time                      0 days 02:13:07.517000
# Driver                                       VER
# DriverNumber                                   1
# LapTime                   0 days 00:01:39.541000
# LapNumber                                   37.0
# Stint                                        3.0
# PitOutTime                                   NaT
# PitInTime                                    NaT
# Sector1Time               0 days 00:00:26.879000
# Sector2Time               0 days 00:00:39.756000
# Sector3Time               0 days 00:00:32.906000
# Sector1SessionTime        0 days 02:11:54.855000
# Sector2SessionTime        0 days 02:12:34.611000
# Sector3SessionTime        0 days 02:13:07.517000
# SpeedI1                                    205.0
# SpeedI2                                    184.0
# SpeedFL                                    204.0
# SpeedST                                    327.0
# IsPersonalBest                              True
# Compound                                  MEDIUM
# TyreLife                                     2.0
# FreshTyre                                   True
# Team                             Red Bull Racing
# LapStartTime              0 days 02:11:27.976000
# LapStartDate          2022-10-23 20:12:27.987000
# TrackStatus                                    1
# Position                                     5.0
# Deleted                                    False
# DeletedReason
# FastF1Generated                            False
# IsAccurate                                  True
# Name: 36, dtype: object

# %%
# Then you get the telemetry of that lap
fastest.get_telemetry()
# Out:
#                        Date            SessionTime DriverAhead  \
# 2   2022-10-23 20:12:27.987 0 days 02:11:27.976000
# 3   2022-10-23 20:12:28.047 0 days 02:11:28.036000
# 4   2022-10-23 20:12:28.051 0 days 02:11:28.040000
# 5   2022-10-23 20:12:28.127 0 days 02:11:28.116000
# 6   2022-10-23 20:12:28.211 0 days 02:11:28.200000          16
# ..                      ...                    ...         ...
# 761 2022-10-23 20:14:07.108 0 days 02:13:07.097000          16
# 762 2022-10-23 20:14:07.172 0 days 02:13:07.161000          16
# 763 2022-10-23 20:14:07.308 0 days 02:13:07.297000          16
# 764 2022-10-23 20:14:07.452 0 days 02:13:07.441000          16
# 765 2022-10-23 20:14:07.528 0 days 02:13:07.517000          16
#
#      DistanceToDriverAhead                   Time    RPM  Speed  nGear  \
# 2                49.156111        0 days 00:00:00  11107    210      4
# 3                49.156111 0 days 00:00:00.060000  11214    213      4
# 4                49.156111 0 days 00:00:00.064000  11427    218      5
# 5                49.156111 0 days 00:00:00.140000  11564    222      5
# 6                49.156111 0 days 00:00:00.224000  11702    227      5
# ..                     ...                    ...    ...    ...    ...
# 761              53.857778 0 days 00:01:39.121000  11090    203      4
# 762              54.163333 0 days 00:01:39.185000  10784    207      5
# 763              54.668889 0 days 00:01:39.321000  11033    210      5
# 764              55.174444 0 days 00:01:39.465000  11283    213      5
# 765              55.174444 0 days 00:01:39.541000  11359    217      5
#
#      Throttle  Brake  DRS         Source     Distance  RelativeDistance  \
# 2         100  False   12  interpolation     1.786978          0.000329
# 3         100  False   12            pos     5.525338          0.001018
# 4         100  False   12            car     5.775556          0.001064
# 5         100  False   12            pos    10.553235          0.001944
# 6         100  False   12            car    15.864444          0.002923
# ..        ...    ...  ...            ...          ...               ...
# 761       100  False   12            pos  5397.381362          0.994445
# 762       100  False   12            car  5401.096389          0.995130
# 763       100  False   12            pos  5409.058248          0.996597
# 764       100  False   12            car  5417.663056          0.998182
# 765       100  False   12  interpolation  5422.308729          0.999038
#
#       Status     X    Y     Z
# 2    OnTrack -1271 -444  1315
# 3    OnTrack -1243 -460  1303
# 4    OnTrack -1241 -461  1302
# 5    OnTrack -1204 -490  1302
# 6    OnTrack -1154 -527  1301
# ..       ...   ...  ...   ...
# 761  OnTrack -1479 -277  1302
# 762  OnTrack -1450 -298  1302
# 763  OnTrack -1379 -354  1302
# 764  OnTrack -1306 -410  1301
# 765  OnTrack -1269 -437  1300
#
# [764 rows x 18 columns]

# %%
# Creating a list of lists that will receive the data to transform to a DataFrame
# This info below will be the name of the columns
information = [['Throttle_1', 'Throttle_2', 'Throttle_3', 
                'nGear_1', 'nGear_2', 'nGear_3',
                'Track']]

# %%
# Circuits by their most popular names and their countries
# Country is required to make a verification of the request
circuits = {
            'Abu Dhabi': 'Abu Dhabi', 
            'Austin': 'United States',
            'Australia': 'Australia',
            'Austria': 'Austria',
            'Bahrain': 'Bahrain',
            'Baku': 'Azerbaijan',
            'Brazil': 'Brazil',
            'Canada': 'Canada',
            'France': 'France',
            'Hungary': 'Hungary',
            'Japan': 'Japan',
            'Mexico': 'Mexico',
            'Monaco': 'Monaco',
            'Monza': 'Italy',
            'Saudi Arabia': 'Saudi Arabia',
            'Silverstone': 'Great Britain',
            'Spa-Francorchamps': 'Belgium',
            'Spain': 'Spain',
            }

# %%
# %%time
for circuit, country in circuits.items():
    print()
    for year in range(2018, 2024):
        # Skip races that didn't happened
        if year == 2023 and circuit not in ['Australia', 'Baku', 'Bahrain', 'Saudi Arabia', 'Monaco', 'Spain']:
            continue
        print(f"\n{circuit} {year} started\n")
        
        try:
            quali = ff1.get_session(year, circuit, 'Q')
            if quali.event.Country != country:
                print(f"{circuit} {year} race not found\n")
                continue
            quali.load()
        except:
            quali = None
            print(f"{circuit} {year} race not found\n")

        try:
            race = ff1.get_session(year, circuit, 'R')
            if race.event.Country != country:
                continue
            race.load()
        except:
            race = None

        if quali and race:
            print('Quali and race loaded\n')
        
        c = 0
        for event in [quali, race]:
            c+=1
            if not quali:
                continue
            if not race:
                continue

            print(f"Started {'quali' if c == 1 else 'race'} of {year}")

            try:
                laps = event.laps
            except:
                print('Laps not loaded\n')

                continue
            for driver in event.results['Abbreviation']:
                lap = laps.pick_driver(driver).pick_fastest()
                # Get the time of each sector
                s1t = lap['Sector1Time']
                s2t = lap['Sector2Time']
                s3t = lap['Sector3Time']

                try:
                    tel = lap.get_telemetry()
                except:
                    print(f'{driver} has no telemetry data')
                    continue
                    
                # Slicing the telemetry for each sector
                s1 = tel[tel['Time'] <= s1t]
                s2 = tel[(tel['Time'] > s1t) & (tel['Time'] <= s1t + s2t)]
                s3 = tel[(tel['Time'] > s1t + s2t) & (tel['Time'] <= s1t + s2t + s3t)]

                sectors = [s1, s2, s3]
               
                # Getting average of each of information in each sector
                info = [sectors[i]['Throttle'].mean() for i in range(3)]
                info.extend(sectors[i]['nGear'].mean() for i in range(3))
                info.extend([circuit])
                information.append(info)
            print(f"\nEnded {'quali' if c == 1 else 'race'} of {year}\n")
# Out:
# Hungary 2018 started
#
# Quali and race loaded
#
# Started quali of 2018
#
# Ended quali of 2018
#
# Started race of 2018
# LEC has no telemetry data
#
# Ended race of 2018
#
#
# Hungary 2019 started
#
# Quali and race loaded
#
# Started quali of 2019
#
# Ended quali of 2019
#
# Started race of 2019
#
# Ended race of 2019
#
#
# Hungary 2020 started
#
# Quali and race loaded
#
# Started quali of 2020
#
# Ended quali of 2020
#
# Started race of 2020
#
# Ended race of 2020
#
#
# Hungary 2021 started
#
# Quali and race loaded
#
# Started quali of 2021
# MSC has no telemetry data
#
# Ended quali of 2021
#
# Started race of 2021
# MAZ has no telemetry data
# NOR has no telemetry data
# BOT has no telemetry data
# PER has no telemetry data
# LEC has no telemetry data
# STR has no telemetry data
#
# Ended race of 2021
#
#
# Hungary 2022 started
#
# Quali and race loaded
#
# Started quali of 2022
#
# Ended quali of 2022
#
# Started race of 2022
#
# Ended race of 2022
#
#
#
# Japan 2018 started
#
# Quali and race loaded
#
# Started quali of 2018
#
# Ended quali of 2018
#
# Started race of 2018
#
# Ended race of 2018
#
#
# Japan 2019 started
#
# Quali and race loaded
#
# Started quali of 2019
# MAG has no telemetry data
# KUB has no telemetry data
#
# Ended quali of 2019
#
# Started race of 2019
#
# Ended race of 2019
#
#
# Japan 2020 started
#
# Japan 2020 race not found
#
#
# Japan 2021 started
#
# Japan 2021 race not found
#
#
# Japan 2022 started
#
# Quali and race loaded
#
# Started quali of 2022
#
# Ended quali of 2022
#
# Started race of 2022
# SAI has no telemetry data
# ALB has no telemetry data
#
# Ended race of 2022
#
#
#
# Mexico 2018 started
#
# Quali and race loaded
#
# Started quali of 2018
#
# Ended quali of 2018
#
# Started race of 2018
#
# Ended race of 2018
#
#
# Mexico 2019 started
#
# Quali and race loaded
#
# Started quali of 2019
#
# Ended quali of 2019
#
# Started race of 2019
#
# Ended race of 2019
#
#
# Mexico 2020 started
#
# Mexico 2020 race not found
#
#
# Mexico 2021 started
#
# Quali and race loaded
#
# Started quali of 2021
#
# Ended quali of 2021
#
# Started race of 2021
# MSC has no telemetry data
# TSU has no telemetry data
#
# Ended race of 2021
#
#
# Mexico 2022 started
#
# Quali and race loaded
#
# Started quali of 2022
#
# Ended quali of 2022
#
# Started race of 2022
#
# Ended race of 2022
#
#
#
# Monaco 2018 started
#
# Quali and race loaded
#
# Started quali of 2018
# VER has no telemetry data
#
# Ended quali of 2018
#
# Started race of 2018
#
# Ended race of 2018
#
#
# Monaco 2019 started
#
# Quali and race loaded
#
# Started quali of 2019
#
# Ended quali of 2019
#
# Started race of 2019
#
# Ended race of 2019
#
#
# Monaco 2020 started
#
# Monaco 2020 race not found
#
#
# Monaco 2021 started
#
# Quali and race loaded
#
# Started quali of 2021
# MSC has no telemetry data
#
# Ended quali of 2021
#
# Started race of 2021
# LEC has no telemetry data
#
# Ended race of 2021
#
#
# Monaco 2022 started
#
# Quali and race loaded
#
# Started quali of 2022
#
# Ended quali of 2022
#
# Started race of 2022
#
# Ended race of 2022
#
#
# Monaco 2023 started
#
# Quali and race loaded
#
# Started quali of 2023
#
# Ended quali of 2023
#
# Started race of 2023
#
# Ended race of 2023
#
#
#
# Monza 2018 started
#
# Quali and race loaded
#
# Started quali of 2018
#
# Ended quali of 2018
#
# Started race of 2018
# HAR has no telemetry data
#
# Ended race of 2018
#
#
# Monza 2019 started
#
# Quali and race loaded
#
# Started quali of 2019
# VER has no telemetry data
#
# Ended quali of 2019
#
# Started race of 2019
#
# Ended race of 2019
#
#
# Monza 2020 started
#
# Quali and race loaded
#
# Started quali of 2020
#
# Ended quali of 2020
#
# Started race of 2020
#
# Ended race of 2020
#
#
# Monza 2021 started
#
# Quali and race loaded
#
# Started quali of 2021
#
# Ended quali of 2021
#
# Started race of 2021
# TSU has no telemetry data
#
# Ended race of 2021
#
#
# Monza 2022 started
#
# Quali and race loaded
#
# Started quali of 2022
#
# Ended quali of 2022
#
# Started race of 2022
#
# Ended race of 2022
#
#
#
# Saudi Arabia 2018 started
#
# Saudi Arabia 2018 race not found
#
#
# Saudi Arabia 2019 started
#
# Saudi Arabia 2019 race not found
#
#
# Saudi Arabia 2020 started
#
# Saudi Arabia 2020 race not found
#
#
# Saudi Arabia 2021 started
#
# Quali and race loaded
#
# Started quali of 2021
#
# Ended quali of 2021
#
# Started race of 2021
#
# Ended race of 2021
#
#
# Saudi Arabia 2022 started
#
# Quali and race loaded
#
# Started quali of 2022
# TSU has no telemetry data
#
# Ended quali of 2022
#
# Started race of 2022
# TSU has no telemetry data
# nan has no telemetry data
#
# Ended race of 2022
#
#
# Saudi Arabia 2023 started
#
# Quali and race loaded
#
# Started quali of 2023
#
# Ended quali of 2023
#
# Started race of 2023
#
# Ended race of 2023
#
#
#
# Silverstone 2018 started
#
# Quali and race loaded
#
# Started quali of 2018
# STR has no telemetry data
# HAR has no telemetry data
#
# Ended quali of 2018
#
# Started race of 2018
# HAR has no telemetry data
#
# Ended race of 2018
#
#
# Silverstone 2019 started
#
# Quali and race loaded
#
# Started quali of 2019
#
# Ended quali of 2019
#
# Started race of 2019
#
# Ended race of 2019
#
#
# Silverstone 2020 started
#
# Quali and race loaded
#
# Started quali of 2020
#
# Ended quali of 2020
#
# Started race of 2020
# MAG has no telemetry data
# HUL has no telemetry data
#
# Ended race of 2020
#
#
# Silverstone 2021 started
#
# Quali and race loaded
#
# Started quali of 2021
#
# Ended quali of 2021
#
# Started race of 2021
# VER has no telemetry data
#
# Ended race of 2021
#
#
# Silverstone 2022 started
#
# Quali and race loaded
#
# Started quali of 2022
#
# Ended quali of 2022
#
# Started race of 2022
# RUS has no telemetry data
# ZHO has no telemetry data
# ALB has no telemetry data
#
# Ended race of 2022
#
#
#
# Spa-Francorchamps 2018 started
#
# Quali and race loaded
#
# Started quali of 2018
#
# Ended quali of 2018
#
# Started race of 2018
# LEC has no telemetry data
# ALO has no telemetry data
# HUL has no telemetry data
#
# Ended race of 2018
#
#
# Spa-Francorchamps 2019 started
#
# Quali and race loaded
#
# Started quali of 2019
# KUB has no telemetry data
#
# Ended quali of 2019
#
# Started race of 2019
# SAI has no telemetry data
# VER has no telemetry data
#
# Ended race of 2019
#
#
# Spa-Francorchamps 2020 started
#
# Quali and race loaded
#
# Started quali of 2020
#
# Ended quali of 2020
#
# Started race of 2020
# SAI has no telemetry data
#
# Ended race of 2020
#
#
# Spa-Francorchamps 2021 started
#
# Quali and race loaded
#
# Started quali of 2021
#
# Ended quali of 2021
#
# Started race of 2021
# VER has no telemetry data
# RUS has no telemetry data
# HAM has no telemetry data
# RIC has no telemetry data
# VET has no telemetry data
# GAS has no telemetry data
# OCO has no telemetry data
# LEC has no telemetry data
# LAT has no telemetry data
# SAI has no telemetry data
# ALO has no telemetry data
# BOT has no telemetry data
# GIO has no telemetry data
# NOR has no telemetry data
# TSU has no telemetry data
# MSC has no telemetry data
# MAZ has no telemetry data
# RAI has no telemetry data
# PER has no telemetry data
# STR has no telemetry data
#
# Ended race of 2021
#
#
# Spa-Francorchamps 2022 started
#
# Quali and race loaded
#
# Started quali of 2022
#
# Ended quali of 2022
#
# Started race of 2022
# BOT has no telemetry data
# HAM has no telemetry data
#
# Ended race of 2022
#
#
#
# Spain 2018 started
#
# Quali and race loaded
#
# Started quali of 2018
# HAR has no telemetry data
#
# Ended quali of 2018
#
# Started race of 2018
# GRO has no telemetry data
# GAS has no telemetry data
# HUL has no telemetry data
#
# Ended race of 2018
#
#
# Spain 2019 started
#
# Quali and race loaded
#
# Started quali of 2019
#
# Ended quali of 2019
#
# Started race of 2019
#
# Ended race of 2019
#
#
# Spain 2020 started
#
# Quali and race loaded
#
# Started quali of 2020
#
# Ended quali of 2020
#
# Started race of 2020
#
# Ended race of 2020
#
#
# Spain 2021 started
#
# Quali and race loaded
#
# Started quali of 2021
#
# Ended quali of 2021
#
# Started race of 2021
#
# Ended race of 2021
#
#
# Spain 2022 started
#
# Quali and race loaded
#
# Started quali of 2022
#
# Ended quali of 2022
#
# Started race of 2022
#
# Ended race of 2022
#
#
# Spain 2023 started
#
# Quali and race loaded
#
# Started quali of 2023
#
# Ended quali of 2023
#
# Started race of 2023
#
# Ended race of 2023
#
# CPU times: total: 15min 44s
# Wall time: 17min 4s

# %%
dataset = pd.DataFrame(information[1:], columns=information[0])
dataset = dataset.dropna()

# %%
dataset.to_csv('formula_data.csv', index=False)
